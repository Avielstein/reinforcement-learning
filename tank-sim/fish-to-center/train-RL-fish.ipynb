# %% [markdown]
# # Enhanced Fish Tank Reinforcement Learning Training
#
# This notebook provides an enhanced training environment for the fish tank RL problem with:
#
# - Improved training algorithms (A2C)
# - Better visualization and monitoring
# - Model saving/loading capabilities
# - Performance comparison tools
#
# The implementation is modularized into utility files for better maintainability.

# %%
# Install required packages if needed
# !pip install torch gymnasium matplotlib numpy

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import warnings

# Import our utilities
from utils import (
    FishTankEnv, WaterCurrent, ActorCritic, A2CLearner,
    run_training_visualization, test_trained_model,
    SEED
)

# Notebook friendliness
plt.ion()
warnings.filterwarnings("ignore", category=UserWarning, message=".*cache_frame_data.*")

# Set random seeds for reproducibility
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

print("All imports successful!")
print("Fish Tank RL environment ready for training.")
# Out:
# All imports successful!
# Fish Tank RL environment ready for training.

# %% [markdown]
# ## Quick Environment Test
#
# Let's test the environment to make sure everything is working:

# %%
# Test the environment
env = FishTankEnv()
obs = env.reset()

print(f"Environment created successfully!")
print(f"Observation space: {env.obs_dim} dimensions")
print(f"Action space: {env.act_dim} dimensions")
print(f"Initial observation: {obs}")
print(f"Fish position: {env.position}")
print(f"Number of currents: {len(env.currents)}")

# Take a random step
action = np.random.uniform(-1, 1, env.act_dim)
next_obs, reward, done, info = env.step(action)
print(f"\nAfter random action {action}:")
print(f"New observation: {next_obs}")
print(f"Reward: {reward:.4f}")
print(f"Done: {done}")
# Out:
# Environment created successfully!
# Observation space: 4 dimensions
# Action space: 2 dimensions
# Initial observation: [ 0.6648853 -0.5753218  0.         0.       ]
# Fish position: [83.24426408 21.23391107]
# Number of currents: 2
#
# After random action [-0.63635007 -0.63319098]:
# New observation: [ 0.6636126  -0.57658815 -0.02121167 -0.02110637]
# Reward: -0.0877
# Done: False

# %% [markdown]
# ## Start Training with Live Visualization
#
# Run this cell to start training the fish agent with real-time visualization. The training will run in a background thread while showing:
#
# - Fish movement in the tank
# - Water currents (cyan circles and arrows)
# - Training metrics (reward and distance to center)
#
# **Note:** Close the plot window to stop training and save the best model.

# %%
# Start training with visualization
learner = run_training_visualization()

print("\nTraining completed!")
print(f"Total episodes trained: {learner.episode_count}")
print(f"Best average return: {learner.best_return:.2f}")
# Out:
# Best model saved! Mean return: -26.20
#
# Training completed!
# Total episodes trained: 1
# Best average return: -26.20

# %% [markdown]
# ## Test the Trained Model
#
# Visualize how well the trained fish performs by showing multiple episode trajectories:

# %%
# Test the trained model
if 'learner' in locals():
    test_trained_model(learner, num_episodes=5)
else:
    print("No trained model available. Please run the training cell first.")

# %% [markdown]
# ## Load and Test a Saved Model
#
# If you have a previously saved model, you can load and test it:

# %%
# Load a saved model
try:
    # Create a new learner and load the saved model
    saved_learner = A2CLearner()
    saved_learner.load_model('best_fish_policy.pt')
    
    print("Successfully loaded saved model!")
    
    # Test the loaded model
    test_trained_model(saved_learner, num_episodes=3)
    
except FileNotFoundError:
    print("No saved model found. Train a model first to create 'best_fish_policy.pt'")
except Exception as e:
    print(f"Error loading model: {e}")
# Out:
# Successfully loaded saved model!

# %% [markdown]
# ## Manual Training (Without Visualization)
#
# For faster training without visualization, you can train manually:

# %%
# Manual training without visualization
manual_learner = A2CLearner()

print("Starting manual training...")
print("Training for 10 steps (this may take a while)")

for step in range(1000):
    manual_learner.train_step()
    
    if step % 2 == 0:  # Print every 2 steps
        mean_return = np.mean(manual_learner.ep_returns) if manual_learner.ep_returns else 0
        print(f"Step {step+1}/10 - Episodes: {manual_learner.episode_count}, Mean Return: {mean_return:.2f}")

print("\nManual training completed!")
print(f"Final episodes: {manual_learner.episode_count}")
print(f"Best return: {manual_learner.best_return:.2f}")

# Save the manually trained model
manual_learner.save_model('best_fish_policy.pt')
print("Model saved as 'best_fish_policy.pt'")
# Out:
# Starting manual training...
# Training for 10 steps (this may take a while)
# Step 1/10 - Episodes: 1, Mean Return: -68.16
# Step 3/10 - Episodes: 3, Mean Return: -48.65
# Step 5/10 - Episodes: 5, Mean Return: -47.61
# Step 7/10 - Episodes: 7, Mean Return: -45.42
# Step 9/10 - Episodes: 9, Mean Return: -50.49
# Step 11/10 - Episodes: 11, Mean Return: -49.29
# Step 13/10 - Episodes: 13, Mean Return: -47.16
# Step 15/10 - Episodes: 15, Mean Return: -44.78
# Step 17/10 - Episodes: 17, Mean Return: -43.74
# Step 19/10 - Episodes: 19, Mean Return: -44.04
# Step 21/10 - Episodes: 21, Mean Return: -43.65
# Step 23/10 - Episodes: 23, Mean Return: -43.77
# Step 25/10 - Episodes: 25, Mean Return: -43.54
# Step 27/10 - Episodes: 27, Mean Return: -43.72
# Step 29/10 - Episodes: 29, Mean Return: -42.65
# Step 31/10 - Episodes: 31, Mean Return: -41.89
# Step 33/10 - Episodes: 33, Mean Return: -40.66
# Step 35/10 - Episodes: 35, Mean Return: -40.84
# Step 37/10 - Episodes: 37, Mean Return: -40.54
# Step 39/10 - Episodes: 39, Mean Return: -39.18
# Step 41/10 - Episodes: 41, Mean Return: -38.72
# Step 43/10 - Episodes: 43, Mean Return: -38.35
# Step 45/10 - Episodes: 45, Mean Return: -38.64
# Step 47/10 - Episodes: 47, Mean Return: -37.69
# Step 49/10 - Episodes: 49, Mean Return: -37.35
# Step 51/10 - Episodes: 51, Mean Return: -37.59
# Step 53/10 - Episodes: 53, Mean Return: -38.07
# Step 55/10 - Episodes: 55, Mean Return: -38.30
# Step 57/10 - Episodes: 57, Mean Return: -38.14
# Step 59/10 - Episodes: 59, Mean Return: -38.15
# Step 61/10 - Episodes: 61, Mean Return: -38.38
# Step 63/10 - Episodes: 63, Mean Return: -38.16
# Step 65/10 - Episodes: 65, Mean Return: -37.76
# Step 67/10 - Episodes: 67, Mean Return: -37.45
# Step 69/10 - Episodes: 69, Mean Return: -37.79
# Step 71/10 - Episodes: 71, Mean Return: -37.75
# Step 73/10 - Episodes: 73, Mean Return: -37.62
# Step 75/10 - Episodes: 75, Mean Return: -37.96
# Step 77/10 - Episodes: 77, Mean Return: -37.90
# Step 79/10 - Episodes: 79, Mean Return: -37.62
# Step 81/10 - Episodes: 81, Mean Return: -36.91
# Step 83/10 - Episodes: 83, Mean Return: -36.84
# Step 85/10 - Episodes: 85, Mean Return: -36.25
# Step 87/10 - Episodes: 87, Mean Return: -36.14
# Step 89/10 - Episodes: 89, Mean Return: -35.75
# Step 91/10 - Episodes: 91, Mean Return: -35.92
# Step 93/10 - Episodes: 93, Mean Return: -36.01
# Step 95/10 - Episodes: 95, Mean Return: -36.28
# Step 97/10 - Episodes: 97, Mean Return: -35.91
# Step 99/10 - Episodes: 99, Mean Return: -35.66
# Step 101/10 - Episodes: 101, Mean Return: -35.54
# Step 103/10 - Episodes: 103, Mean Return: -35.23
# Step 105/10 - Episodes: 105, Mean Return: -35.09
# Step 107/10 - Episodes: 107, Mean Return: -35.09
# Step 109/10 - Episodes: 109, Mean Return: -35.47
# Step 111/10 - Episodes: 111, Mean Return: -35.37
# Step 113/10 - Episodes: 113, Mean Return: -35.31
# Step 115/10 - Episodes: 115, Mean Return: -35.31
# Step 117/10 - Episodes: 117, Mean Return: -35.38
# Step 119/10 - Episodes: 119, Mean Return: -35.44
# Step 121/10 - Episodes: 121, Mean Return: -35.61
# Step 123/10 - Episodes: 123, Mean Return: -35.62
# Step 125/10 - Episodes: 125, Mean Return: -35.60
# Step 127/10 - Episodes: 127, Mean Return: -35.49
# Step 129/10 - Episodes: 129, Mean Return: -35.31
# Step 131/10 - Episodes: 131, Mean Return: -35.03
# Step 133/10 - Episodes: 133, Mean Return: -34.72
# Step 135/10 - Episodes: 135, Mean Return: -34.85
# Step 137/10 - Episodes: 137, Mean Return: -34.64
# Step 139/10 - Episodes: 139, Mean Return: -34.63
# Step 141/10 - Episodes: 141, Mean Return: -34.46
# Step 143/10 - Episodes: 143, Mean Return: -34.38
# Step 145/10 - Episodes: 145, Mean Return: -34.35
# Step 147/10 - Episodes: 147, Mean Return: -34.41
# Step 149/10 - Episodes: 149, Mean Return: -34.19
# Step 151/10 - Episodes: 151, Mean Return: -34.18
# Step 153/10 - Episodes: 153, Mean Return: -34.06
# Step 155/10 - Episodes: 155, Mean Return: -33.92
# Step 157/10 - Episodes: 157, Mean Return: -33.59
# Step 159/10 - Episodes: 159, Mean Return: -33.56
# Step 161/10 - Episodes: 161, Mean Return: -33.27
# Step 163/10 - Episodes: 163, Mean Return: -33.05
# Step 165/10 - Episodes: 165, Mean Return: -32.76
# Step 167/10 - Episodes: 167, Mean Return: -32.63
# Step 169/10 - Episodes: 169, Mean Return: -32.59
# Step 171/10 - Episodes: 171, Mean Return: -32.39
# Step 173/10 - Episodes: 173, Mean Return: -32.49
# Step 175/10 - Episodes: 175, Mean Return: -32.68
# Step 177/10 - Episodes: 177, Mean Return: -32.52
# Step 179/10 - Episodes: 179, Mean Return: -32.34
# Step 181/10 - Episodes: 181, Mean Return: -32.33
# Step 183/10 - Episodes: 183, Mean Return: -32.32
# Step 185/10 - Episodes: 185, Mean Return: -32.55
# Step 187/10 - Episodes: 187, Mean Return: -33.11
# Step 189/10 - Episodes: 189, Mean Return: -33.36
# Step 191/10 - Episodes: 191, Mean Return: -33.70
# Step 193/10 - Episodes: 193, Mean Return: -34.24
# Step 195/10 - Episodes: 195, Mean Return: -34.75
# Step 197/10 - Episodes: 197, Mean Return: -35.03
# Step 199/10 - Episodes: 199, Mean Return: -34.90
# Step 201/10 - Episodes: 201, Mean Return: -34.66
# Step 203/10 - Episodes: 203, Mean Return: -34.26
# Step 205/10 - Episodes: 205, Mean Return: -33.81
# Step 207/10 - Episodes: 207, Mean Return: -33.41
# Step 209/10 - Episodes: 209, Mean Return: -32.92
# Step 211/10 - Episodes: 211, Mean Return: -32.66
# Step 213/10 - Episodes: 213, Mean Return: -32.55
# Step 215/10 - Episodes: 215, Mean Return: -32.64
# Step 217/10 - Episodes: 217, Mean Return: -32.50
# Step 219/10 - Episodes: 219, Mean Return: -32.45
# Step 221/10 - Episodes: 221, Mean Return: -32.59
# Step 223/10 - Episodes: 223, Mean Return: -32.44
# Step 225/10 - Episodes: 225, Mean Return: -32.33
# Step 227/10 - Episodes: 227, Mean Return: -32.04
# Step 229/10 - Episodes: 229, Mean Return: -31.94
# Step 231/10 - Episodes: 231, Mean Return: -31.93
# Step 233/10 - Episodes: 233, Mean Return: -32.01
# Step 235/10 - Episodes: 235, Mean Return: -31.85
# Step 237/10 - Episodes: 237, Mean Return: -31.74
# Step 239/10 - Episodes: 239, Mean Return: -32.27
# Step 241/10 - Episodes: 241, Mean Return: -32.31
# Step 243/10 - Episodes: 243, Mean Return: -32.39
# Step 245/10 - Episodes: 245, Mean Return: -32.18
# Step 247/10 - Episodes: 247, Mean Return: -32.14
# Step 249/10 - Episodes: 249, Mean Return: -31.90
# Step 251/10 - Episodes: 251, Mean Return: -31.42
# Step 253/10 - Episodes: 253, Mean Return: -30.95
# Step 255/10 - Episodes: 255, Mean Return: -30.84
# Step 257/10 - Episodes: 257, Mean Return: -30.84
# Step 259/10 - Episodes: 259, Mean Return: -30.70
# Step 261/10 - Episodes: 261, Mean Return: -30.52
# Step 263/10 - Episodes: 263, Mean Return: -30.41
# Step 265/10 - Episodes: 265, Mean Return: -30.27
# Step 267/10 - Episodes: 267, Mean Return: -30.41
# Step 269/10 - Episodes: 269, Mean Return: -30.30
# Step 271/10 - Episodes: 271, Mean Return: -30.26
# Step 273/10 - Episodes: 273, Mean Return: -30.25
# Step 275/10 - Episodes: 275, Mean Return: -30.04
# Step 277/10 - Episodes: 277, Mean Return: -29.80
# Step 279/10 - Episodes: 279, Mean Return: -29.78
# Step 281/10 - Episodes: 281, Mean Return: -30.00
# Step 283/10 - Episodes: 283, Mean Return: -29.95
# Step 285/10 - Episodes: 285, Mean Return: -30.20
# Step 287/10 - Episodes: 287, Mean Return: -30.20
# Step 289/10 - Episodes: 289, Mean Return: -30.21
# Step 291/10 - Episodes: 291, Mean Return: -29.69
# Step 293/10 - Episodes: 293, Mean Return: -29.19
# Step 295/10 - Episodes: 295, Mean Return: -28.81
# Step 297/10 - Episodes: 297, Mean Return: -28.62
# Step 299/10 - Episodes: 299, Mean Return: -28.43
# Step 301/10 - Episodes: 301, Mean Return: -28.28
# Step 303/10 - Episodes: 303, Mean Return: -28.41
# Step 305/10 - Episodes: 305, Mean Return: -28.27
# Step 307/10 - Episodes: 307, Mean Return: -27.99
# Step 309/10 - Episodes: 309, Mean Return: -27.70
# Step 311/10 - Episodes: 311, Mean Return: -27.58
# Step 313/10 - Episodes: 313, Mean Return: -27.32
# Step 315/10 - Episodes: 315, Mean Return: -26.96
# Step 317/10 - Episodes: 317, Mean Return: -26.51
# Step 319/10 - Episodes: 319, Mean Return: -26.20
# Step 321/10 - Episodes: 321, Mean Return: -25.68
# Step 323/10 - Episodes: 323, Mean Return: -25.41
# Step 325/10 - Episodes: 325, Mean Return: -25.21
# Step 327/10 - Episodes: 327, Mean Return: -24.92
# Step 329/10 - Episodes: 329, Mean Return: -24.76
# Step 331/10 - Episodes: 331, Mean Return: -24.54
# Step 333/10 - Episodes: 333, Mean Return: -24.32
# Step 335/10 - Episodes: 335, Mean Return: -23.85
# Step 337/10 - Episodes: 337, Mean Return: -23.73
# Step 339/10 - Episodes: 339, Mean Return: -23.44
# Step 341/10 - Episodes: 341, Mean Return: -23.25
# Step 343/10 - Episodes: 343, Mean Return: -23.04
# Step 345/10 - Episodes: 345, Mean Return: -22.93
# Step 347/10 - Episodes: 347, Mean Return: -22.70
# Step 349/10 - Episodes: 349, Mean Return: -22.72
# Step 351/10 - Episodes: 351, Mean Return: -22.33
# Step 353/10 - Episodes: 353, Mean Return: -22.08
# Step 355/10 - Episodes: 355, Mean Return: -21.91
# Step 357/10 - Episodes: 357, Mean Return: -21.73
# Step 359/10 - Episodes: 359, Mean Return: -21.51
# Step 361/10 - Episodes: 361, Mean Return: -21.41
# Step 363/10 - Episodes: 363, Mean Return: -21.22
# Step 365/10 - Episodes: 365, Mean Return: -21.05
# Step 367/10 - Episodes: 367, Mean Return: -20.84
# Step 369/10 - Episodes: 369, Mean Return: -20.52
# Step 371/10 - Episodes: 371, Mean Return: -20.28
# Step 373/10 - Episodes: 373, Mean Return: -20.14
# Step 375/10 - Episodes: 375, Mean Return: -19.81
# Step 377/10 - Episodes: 377, Mean Return: -19.70
# Step 379/10 - Episodes: 379, Mean Return: -19.70
# Step 381/10 - Episodes: 381, Mean Return: -19.46
# Step 383/10 - Episodes: 383, Mean Return: -19.21
# Step 385/10 - Episodes: 385, Mean Return: -18.96
# Step 387/10 - Episodes: 387, Mean Return: -18.09
# Step 389/10 - Episodes: 389, Mean Return: -17.73
# Step 391/10 - Episodes: 391, Mean Return: -17.30
# Step 393/10 - Episodes: 393, Mean Return: -16.54
# Step 395/10 - Episodes: 395, Mean Return: -15.70
# Step 397/10 - Episodes: 397, Mean Return: -15.08
# Step 399/10 - Episodes: 399, Mean Return: -14.85
# Step 401/10 - Episodes: 401, Mean Return: -14.54
# Step 403/10 - Episodes: 403, Mean Return: -14.57
# Step 405/10 - Episodes: 405, Mean Return: -14.44
# Step 407/10 - Episodes: 407, Mean Return: -14.36
# Step 409/10 - Episodes: 409, Mean Return: -14.04
# Step 411/10 - Episodes: 411, Mean Return: -13.74
# Step 413/10 - Episodes: 413, Mean Return: -13.50
# Step 415/10 - Episodes: 415, Mean Return: -12.99
# Step 417/10 - Episodes: 417, Mean Return: -12.69
# Step 419/10 - Episodes: 419, Mean Return: -12.43
# Step 421/10 - Episodes: 421, Mean Return: -11.83
# Step 423/10 - Episodes: 423, Mean Return: -11.37
# Step 425/10 - Episodes: 425, Mean Return: -10.97
# Step 427/10 - Episodes: 427, Mean Return: -10.73
# Step 429/10 - Episodes: 429, Mean Return: -10.44
# Step 431/10 - Episodes: 431, Mean Return: -10.06
# Step 433/10 - Episodes: 433, Mean Return: -9.63
# Step 435/10 - Episodes: 435, Mean Return: -9.47
# Step 437/10 - Episodes: 437, Mean Return: -9.23
# Step 439/10 - Episodes: 439, Mean Return: -8.52
# Step 441/10 - Episodes: 441, Mean Return: -8.21
# Step 443/10 - Episodes: 443, Mean Return: -7.81
# Step 445/10 - Episodes: 445, Mean Return: -7.53
# Step 447/10 - Episodes: 447, Mean Return: -7.50
# Step 449/10 - Episodes: 449, Mean Return: -7.46
# Step 451/10 - Episodes: 451, Mean Return: -7.55
# Step 453/10 - Episodes: 453, Mean Return: -7.49
# Step 455/10 - Episodes: 455, Mean Return: -7.19
# Step 457/10 - Episodes: 457, Mean Return: -6.86
# Step 459/10 - Episodes: 459, Mean Return: -6.55
# Step 461/10 - Episodes: 461, Mean Return: -6.20
# Step 463/10 - Episodes: 463, Mean Return: -6.00
# Step 465/10 - Episodes: 465, Mean Return: -5.86
# Step 467/10 - Episodes: 467, Mean Return: -5.45
# Step 469/10 - Episodes: 469, Mean Return: -5.11
# Step 471/10 - Episodes: 471, Mean Return: -4.63
# Step 473/10 - Episodes: 473, Mean Return: -4.17
# Step 475/10 - Episodes: 475, Mean Return: -3.66
# Step 477/10 - Episodes: 477, Mean Return: -3.41
# Step 479/10 - Episodes: 479, Mean Return: -3.02
# Step 481/10 - Episodes: 481, Mean Return: -2.82
# Step 483/10 - Episodes: 483, Mean Return: -2.49
# Step 485/10 - Episodes: 485, Mean Return: -2.21
# Step 487/10 - Episodes: 487, Mean Return: -1.95
# Step 489/10 - Episodes: 489, Mean Return: -1.76
# Step 491/10 - Episodes: 491, Mean Return: -1.75
# Step 493/10 - Episodes: 493, Mean Return: -1.80
# Step 495/10 - Episodes: 495, Mean Return: -1.59
# Step 497/10 - Episodes: 497, Mean Return: -1.51
# Step 499/10 - Episodes: 499, Mean Return: -1.44
# Step 501/10 - Episodes: 501, Mean Return: -1.23
# Step 503/10 - Episodes: 503, Mean Return: -0.92
# Step 505/10 - Episodes: 505, Mean Return: -0.69
# Step 507/10 - Episodes: 507, Mean Return: -0.60
# Step 509/10 - Episodes: 509, Mean Return: -0.21
# Step 511/10 - Episodes: 511, Mean Return: 0.06
# Step 513/10 - Episodes: 513, Mean Return: 0.20
# Step 515/10 - Episodes: 515, Mean Return: 0.37
# Step 517/10 - Episodes: 517, Mean Return: -0.12
# Step 519/10 - Episodes: 519, Mean Return: -0.16
# Step 521/10 - Episodes: 521, Mean Return: -0.14
# Step 523/10 - Episodes: 523, Mean Return: 0.08
# Step 525/10 - Episodes: 525, Mean Return: 0.27
# Step 527/10 - Episodes: 527, Mean Return: 0.22
# Step 529/10 - Episodes: 529, Mean Return: 0.42
# Step 531/10 - Episodes: 531, Mean Return: 0.45
# Step 533/10 - Episodes: 533, Mean Return: 0.41
# Step 535/10 - Episodes: 535, Mean Return: 0.39
# Step 537/10 - Episodes: 537, Mean Return: 0.47
# Step 539/10 - Episodes: 539, Mean Return: 0.63
# Step 541/10 - Episodes: 541, Mean Return: 0.49
# Step 543/10 - Episodes: 543, Mean Return: 0.64
# Step 545/10 - Episodes: 545, Mean Return: 0.77
# Step 547/10 - Episodes: 547, Mean Return: 0.99
# Step 549/10 - Episodes: 549, Mean Return: 1.20
# Step 551/10 - Episodes: 551, Mean Return: 1.20
# Step 553/10 - Episodes: 553, Mean Return: 1.23
# Step 555/10 - Episodes: 555, Mean Return: 1.29
# Step 557/10 - Episodes: 557, Mean Return: 1.26
# Step 559/10 - Episodes: 559, Mean Return: 1.44
# Step 561/10 - Episodes: 561, Mean Return: 1.51
# Step 563/10 - Episodes: 563, Mean Return: 1.52
# Step 565/10 - Episodes: 565, Mean Return: 1.50
# Step 567/10 - Episodes: 567, Mean Return: 1.61
# Step 569/10 - Episodes: 569, Mean Return: 1.51
# Step 571/10 - Episodes: 571, Mean Return: 1.32
# Step 573/10 - Episodes: 573, Mean Return: 1.58
# Step 575/10 - Episodes: 575, Mean Return: 1.72
# Step 577/10 - Episodes: 577, Mean Return: 1.88
# Step 579/10 - Episodes: 579, Mean Return: 2.15
# Step 581/10 - Episodes: 581, Mean Return: 2.18
# Step 583/10 - Episodes: 583, Mean Return: 2.36
# Step 585/10 - Episodes: 585, Mean Return: 2.68
# Step 587/10 - Episodes: 587, Mean Return: 2.67
# Step 589/10 - Episodes: 589, Mean Return: 2.78
# Step 591/10 - Episodes: 591, Mean Return: 2.94
# Step 593/10 - Episodes: 593, Mean Return: 3.16
# Step 595/10 - Episodes: 595, Mean Return: 3.19
# Step 597/10 - Episodes: 597, Mean Return: 3.10
# Step 599/10 - Episodes: 599, Mean Return: 3.11
# Step 601/10 - Episodes: 601, Mean Return: 3.12
# Step 603/10 - Episodes: 603, Mean Return: 3.24
# Step 605/10 - Episodes: 605, Mean Return: 3.13
# Step 607/10 - Episodes: 607, Mean Return: 3.09
# Step 609/10 - Episodes: 609, Mean Return: 3.03
# Step 611/10 - Episodes: 611, Mean Return: 2.91
# Step 613/10 - Episodes: 613, Mean Return: 2.94
# Step 615/10 - Episodes: 615, Mean Return: 2.93
# Step 617/10 - Episodes: 617, Mean Return: 2.78
# Step 619/10 - Episodes: 619, Mean Return: 3.02
# Step 621/10 - Episodes: 621, Mean Return: 3.01
# Step 623/10 - Episodes: 623, Mean Return: 2.98
# Step 625/10 - Episodes: 625, Mean Return: 2.82
# Step 627/10 - Episodes: 627, Mean Return: 2.88
# Step 629/10 - Episodes: 629, Mean Return: 2.70
# Step 631/10 - Episodes: 631, Mean Return: 2.72
# Step 633/10 - Episodes: 633, Mean Return: 2.65
# Step 635/10 - Episodes: 635, Mean Return: 2.93
# Step 637/10 - Episodes: 637, Mean Return: 2.97
# Step 639/10 - Episodes: 639, Mean Return: 3.01
# Step 641/10 - Episodes: 641, Mean Return: 3.05
# Step 643/10 - Episodes: 643, Mean Return: 3.00
# Step 645/10 - Episodes: 645, Mean Return: 2.95
# Step 647/10 - Episodes: 647, Mean Return: 2.94
# Step 649/10 - Episodes: 649, Mean Return: 2.80
# Step 651/10 - Episodes: 651, Mean Return: 2.86
# Step 653/10 - Episodes: 653, Mean Return: 2.86
# Step 655/10 - Episodes: 655, Mean Return: 2.98
# Step 657/10 - Episodes: 657, Mean Return: 3.04
# Step 659/10 - Episodes: 659, Mean Return: 2.96
# Step 661/10 - Episodes: 661, Mean Return: 2.80
# Step 663/10 - Episodes: 663, Mean Return: 2.67
# Step 665/10 - Episodes: 665, Mean Return: 2.64
# Step 667/10 - Episodes: 667, Mean Return: 2.83
# Step 669/10 - Episodes: 669, Mean Return: 2.92
# Step 671/10 - Episodes: 671, Mean Return: 2.84
# Step 673/10 - Episodes: 673, Mean Return: 2.86
# Step 675/10 - Episodes: 675, Mean Return: 2.81
# Step 677/10 - Episodes: 677, Mean Return: 2.78
# Step 679/10 - Episodes: 679, Mean Return: 2.70
# Step 681/10 - Episodes: 681, Mean Return: 2.96
# Step 683/10 - Episodes: 683, Mean Return: 2.85
# Step 685/10 - Episodes: 685, Mean Return: 2.98
# Step 687/10 - Episodes: 687, Mean Return: 3.15
# Step 689/10 - Episodes: 689, Mean Return: 3.17
# Step 691/10 - Episodes: 691, Mean Return: 3.01
# Step 693/10 - Episodes: 693, Mean Return: 3.04
# Step 695/10 - Episodes: 695, Mean Return: 3.04
# Step 697/10 - Episodes: 697, Mean Return: 2.93
# Step 699/10 - Episodes: 699, Mean Return: 2.87
# Step 701/10 - Episodes: 701, Mean Return: 2.57
# Step 703/10 - Episodes: 703, Mean Return: 2.51
# Step 705/10 - Episodes: 705, Mean Return: 2.40
# Step 707/10 - Episodes: 707, Mean Return: 2.42
# Step 709/10 - Episodes: 709, Mean Return: 2.33
# Step 711/10 - Episodes: 711, Mean Return: 2.25
# Step 713/10 - Episodes: 713, Mean Return: 2.17
# Step 715/10 - Episodes: 715, Mean Return: 2.15
# Step 717/10 - Episodes: 717, Mean Return: 2.71
# Step 719/10 - Episodes: 719, Mean Return: 2.80
# Step 721/10 - Episodes: 721, Mean Return: 2.71
# Step 723/10 - Episodes: 723, Mean Return: 2.54
# Step 725/10 - Episodes: 725, Mean Return: 2.53
# Step 727/10 - Episodes: 727, Mean Return: 2.64
# Step 729/10 - Episodes: 729, Mean Return: 2.58
# Step 731/10 - Episodes: 731, Mean Return: 2.25
# Step 733/10 - Episodes: 733, Mean Return: 2.10
# Step 735/10 - Episodes: 735, Mean Return: 2.17
# Step 737/10 - Episodes: 737, Mean Return: 2.20
# Step 739/10 - Episodes: 739, Mean Return: 2.03
# Step 741/10 - Episodes: 741, Mean Return: 2.31
# Step 743/10 - Episodes: 743, Mean Return: 2.15
# Step 745/10 - Episodes: 745, Mean Return: 2.35
# Step 747/10 - Episodes: 747, Mean Return: 2.34
# Step 749/10 - Episodes: 749, Mean Return: 2.33
# Step 751/10 - Episodes: 751, Mean Return: 2.31
# Step 753/10 - Episodes: 753, Mean Return: 2.30
# Step 755/10 - Episodes: 755, Mean Return: 2.35
# Step 757/10 - Episodes: 757, Mean Return: 2.38
# Step 759/10 - Episodes: 759, Mean Return: 2.25
# Step 761/10 - Episodes: 761, Mean Return: 2.13
# Step 763/10 - Episodes: 763, Mean Return: 2.08
# Step 765/10 - Episodes: 765, Mean Return: 1.87
# Step 767/10 - Episodes: 767, Mean Return: 1.75
# Step 769/10 - Episodes: 769, Mean Return: 1.79
# Step 771/10 - Episodes: 771, Mean Return: 1.76
# Step 773/10 - Episodes: 773, Mean Return: 1.81
# Step 775/10 - Episodes: 775, Mean Return: 1.88
# Step 777/10 - Episodes: 777, Mean Return: 1.85
# Step 779/10 - Episodes: 779, Mean Return: 1.86
# Step 781/10 - Episodes: 781, Mean Return: 1.73
# Step 783/10 - Episodes: 783, Mean Return: 1.31
# Step 785/10 - Episodes: 785, Mean Return: 1.04
# Step 787/10 - Episodes: 787, Mean Return: 1.05
# Step 789/10 - Episodes: 789, Mean Return: 1.23
# Step 791/10 - Episodes: 791, Mean Return: 1.28
# Step 793/10 - Episodes: 793, Mean Return: 1.01
# Step 795/10 - Episodes: 795, Mean Return: 0.64
# Step 797/10 - Episodes: 797, Mean Return: 0.66
# Step 799/10 - Episodes: 799, Mean Return: 0.82
# Step 801/10 - Episodes: 801, Mean Return: 0.85
# Step 803/10 - Episodes: 803, Mean Return: 0.85
# Step 805/10 - Episodes: 805, Mean Return: 0.96
# Step 807/10 - Episodes: 807, Mean Return: 1.09
# Step 809/10 - Episodes: 809, Mean Return: 1.21
# Step 811/10 - Episodes: 811, Mean Return: 1.31
# Step 813/10 - Episodes: 813, Mean Return: 1.39
# Step 815/10 - Episodes: 815, Mean Return: 1.23
# Step 817/10 - Episodes: 817, Mean Return: 1.33
# Step 819/10 - Episodes: 819, Mean Return: 1.30
# Step 821/10 - Episodes: 821, Mean Return: 1.32
# Step 823/10 - Episodes: 823, Mean Return: 1.12
# Step 825/10 - Episodes: 825, Mean Return: 1.32
# Step 827/10 - Episodes: 827, Mean Return: 1.22
# Step 829/10 - Episodes: 829, Mean Return: 1.38
# Step 831/10 - Episodes: 831, Mean Return: 1.32
# Step 833/10 - Episodes: 833, Mean Return: 1.23
# Step 835/10 - Episodes: 835, Mean Return: 1.22
# Step 837/10 - Episodes: 837, Mean Return: 1.24
# Step 839/10 - Episodes: 839, Mean Return: 1.27
# Step 841/10 - Episodes: 841, Mean Return: 1.36
# Step 843/10 - Episodes: 843, Mean Return: 1.47
# Step 845/10 - Episodes: 845, Mean Return: 1.51
# Step 847/10 - Episodes: 847, Mean Return: 1.75
# Step 849/10 - Episodes: 849, Mean Return: 2.00
# Step 851/10 - Episodes: 851, Mean Return: 1.96
# Step 853/10 - Episodes: 853, Mean Return: 1.94
# Step 855/10 - Episodes: 855, Mean Return: 1.95
# Step 857/10 - Episodes: 857, Mean Return: 1.95
# Step 859/10 - Episodes: 859, Mean Return: 2.09
# Step 861/10 - Episodes: 861, Mean Return: 2.32
# Step 863/10 - Episodes: 863, Mean Return: 2.57
# Step 865/10 - Episodes: 865, Mean Return: 2.76
# Step 867/10 - Episodes: 867, Mean Return: 2.56
# Step 869/10 - Episodes: 869, Mean Return: 2.64
# Step 871/10 - Episodes: 871, Mean Return: 2.68
# Step 873/10 - Episodes: 873, Mean Return: 2.56
# Step 875/10 - Episodes: 875, Mean Return: 2.54
# Step 877/10 - Episodes: 877, Mean Return: 2.38
# Step 879/10 - Episodes: 879, Mean Return: 2.35
# Step 881/10 - Episodes: 881, Mean Return: 2.13
# Step 883/10 - Episodes: 883, Mean Return: 2.12
# Step 885/10 - Episodes: 885, Mean Return: 2.10
# Step 887/10 - Episodes: 887, Mean Return: 1.66
# Step 889/10 - Episodes: 889, Mean Return: 1.46
# Step 891/10 - Episodes: 891, Mean Return: 1.53
# Step 893/10 - Episodes: 893, Mean Return: 1.54
# Step 895/10 - Episodes: 895, Mean Return: 1.58
# Step 897/10 - Episodes: 897, Mean Return: 1.55
# Step 899/10 - Episodes: 899, Mean Return: 1.68
# Step 901/10 - Episodes: 901, Mean Return: 1.95
# Step 903/10 - Episodes: 903, Mean Return: 2.06
# Step 905/10 - Episodes: 905, Mean Return: 2.09
# Step 907/10 - Episodes: 907, Mean Return: 2.14
# Step 909/10 - Episodes: 909, Mean Return: 2.20
# Step 911/10 - Episodes: 911, Mean Return: 2.38
# Step 913/10 - Episodes: 913, Mean Return: 2.46
# Step 915/10 - Episodes: 915, Mean Return: 2.43
# Step 917/10 - Episodes: 917, Mean Return: 2.38
# Step 919/10 - Episodes: 919, Mean Return: 2.40
# Step 921/10 - Episodes: 921, Mean Return: 2.45
# Step 923/10 - Episodes: 923, Mean Return: 2.57
# Step 925/10 - Episodes: 925, Mean Return: 2.51
# Step 927/10 - Episodes: 927, Mean Return: 2.40
# Step 929/10 - Episodes: 929, Mean Return: 2.47
# Step 931/10 - Episodes: 931, Mean Return: 2.87
# Step 933/10 - Episodes: 933, Mean Return: 3.14
# Step 935/10 - Episodes: 935, Mean Return: 3.16
# Step 937/10 - Episodes: 937, Mean Return: 3.27
# Step 939/10 - Episodes: 939, Mean Return: 3.50
# Step 941/10 - Episodes: 941, Mean Return: 3.43
# Step 943/10 - Episodes: 943, Mean Return: 3.54
# Step 945/10 - Episodes: 945, Mean Return: 3.34
# Step 947/10 - Episodes: 947, Mean Return: 3.36
# Step 949/10 - Episodes: 949, Mean Return: 3.41
# Step 951/10 - Episodes: 951, Mean Return: 3.50
# Step 953/10 - Episodes: 953, Mean Return: 3.58
# Step 955/10 - Episodes: 955, Mean Return: 3.56
# Step 957/10 - Episodes: 957, Mean Return: 3.62
# Step 959/10 - Episodes: 959, Mean Return: 3.82
# Step 961/10 - Episodes: 961, Mean Return: 4.06
# Step 963/10 - Episodes: 963, Mean Return: 4.23
# Step 965/10 - Episodes: 965, Mean Return: 4.45
# Step 967/10 - Episodes: 967, Mean Return: 4.55
# Step 969/10 - Episodes: 969, Mean Return: 4.66
# Step 971/10 - Episodes: 971, Mean Return: 4.86
# Step 973/10 - Episodes: 973, Mean Return: 4.97
# Step 975/10 - Episodes: 975, Mean Return: 5.05
# Step 977/10 - Episodes: 977, Mean Return: 5.00
# Step 979/10 - Episodes: 979, Mean Return: 4.92
# Step 981/10 - Episodes: 981, Mean Return: 5.15
# Step 983/10 - Episodes: 983, Mean Return: 5.40
# Step 985/10 - Episodes: 985, Mean Return: 5.71
# Step 987/10 - Episodes: 987, Mean Return: 5.73
# Step 989/10 - Episodes: 989, Mean Return: 5.76
# Step 991/10 - Episodes: 991, Mean Return: 5.90
# Step 993/10 - Episodes: 993, Mean Return: 6.16
# Step 995/10 - Episodes: 995, Mean Return: 6.50
# Step 997/10 - Episodes: 997, Mean Return: 6.41
# Step 999/10 - Episodes: 999, Mean Return: 6.36
#
# Manual training completed!
# Final episodes: 1000
# Best return: 6.51
# Model saved as 'best_fish_policy.pt'

# %% [markdown]
# ## Environment Analysis
#
# Let's analyze the environment and understand the fish's behavior:

# %%
# Analyze environment dynamics
env = FishTankEnv()

# Test different actions and their effects
test_actions = [
    [0, 0],      # No action
    [1, 0],      # Right
    [-1, 0],     # Left  
    [0, 1],      # Up
    [0, -1],     # Down
    [0.5, 0.5],  # Diagonal
]

print("Testing different actions:")
print("Action\t\tReward\t\tNew Position")
print("-" * 50)

for action in test_actions:
    obs = env.reset()
    initial_pos = env.position.copy()
    
    next_obs, reward, done, info = env.step(np.array(action))
    
    print(f"{str(action):12}\t{reward:8.4f}\t{env.position}")

print("\nCurrent positions and strengths:")
for i, current in enumerate(env.currents):
    print(f"Current {i+1}: pos={current.position:.1f}, strength={current.strength:.1f}")
# Out:
# Testing different actions:
# Action		Reward		New Position
# --------------------------------------------------
# [0, 0]      	 -0.0918	[ 2.82769339 59.22488154]
# [1, 0]      	 -0.0826	[44.91658276 90.18811753]
# [-1, 0]     	  0.4240	[50.40516298 56.44857363]
# [0, 1]      	  0.3732	[52.85984122 43.08551235]
# [0, -1]     	 -0.0864	[75.80282673 84.34898901]
# [0.5, 0.5]  	 -0.0912	[ 4.31218097 37.96019062]
#
# Current positions and strengths:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 28
#      26 print("\nCurrent positions and strengths:")
#      27 for i, current in enumerate(env.currents):
# ---> 28     print(f"Current {i+1}: pos={current.position:.1f}, strength={current.strength:.1f}")
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__

# %% [markdown]
# ## Experiment with Hyperparameters
#
# You can modify the constants and retrain to see how different settings affect performance:

# %%
# Example: Create environment with different settings
from utils.constants import *

print("Current hyperparameters:")
print(f"Tank size: {TANK_SIZE}")
print(f"Max velocity: {MAX_VELOCITY}")
print(f"Max force: {MAX_FORCE}")
print(f"Current count: {CURRENT_COUNT}")
print(f"Current strength: {MAX_CURRENT_STRENGTH}")
print(f"Episode length: {EPISODE_LEN}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Learning rate: {POLICY_LR}")

print("\nTo modify these, edit the values in utils/constants.py and restart the kernel.")
# Out:
# Current hyperparameters:
# Tank size: 100.0
# Max velocity: 30.0
# Max force: 10.0
# Current count: 2
# Current strength: 12.0
# Episode length: 1000
# Batch size: 1024
# Learning rate: 0.0003
#
# To modify these, edit the values in utils/constants.py and restart the kernel.
